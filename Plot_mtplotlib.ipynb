# %%
import pandas as pd

# %%
mydata=pd.read_excel(r"C:\Users\Naman\Desktop\Python\Datasets\DataSets-master\Uni_Data.xlsx")

# %%
mydata.shape
# Out:
# (25, 2)

# %%
mydata.keys()
# Out:
# Index(['Input', 'Output'], dtype='object')

# %%
x_input=mydata.Input.values
y_output=mydata.Output.values

# %%
x_input
# Out:
# array([2.5, 5.1, 3.2, 8.5, 3.5, 1.5, 9.2, 5.5, 8.3, 2.7, 7.7, 5.9, 4.5,
#        3.3, 1.1, 8.9, 2.5, 1.9, 6.1, 7.4, 2.7, 4.8, 3.8, 6.9, 7.8])

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(x_input,y_output,'r*')

# %%
plt.title("XvsY")
plt.xlabel("Input")
plt.ylabel("Output")
plt.show()

# %%
plt.plot(x_input,y_output,'r*')
plt.title("XvsY")
plt.xlabel("Input")
plt.ylabel("Output")
plt.show()

# %%
z_output=y_output[::-1]

# %%
plt.plot(x_input,y_output,'r*')
plt.plot(x_input,z_output,'bo')
plt.title("XvsY")
plt.xlabel("Input")
plt.ylabel("Output")
plt.legend(["y_out","z_out"])
plt.show()
