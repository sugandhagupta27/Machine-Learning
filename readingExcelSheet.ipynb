# %%
import pandas as pd

# %%
mydf=pd.read_excel(r"C:\Users\Naman\Desktop\Python\Datasets\DataSets-master\Test_Data.xlsx")

# %%
mydf
# Out:
#     account                              name  \
# 0    211829        Kerluke, Koepp and Hilpert
# 1    320563                    Walter-Trantow
# 2    648336        Bashirian, Kunde and Price
# 3    109996       D'Amore, Gleichner and Bode
# 4    121213                     Bauch-Goldner
# 5    132971  Williamson, Schumm and Hettinger
# 6    145068                        Casper LLC
# 7    205217                  Kovacek-Johnston
# 8    209744                    Champlin-Morar
# 9    212303                    Gerhold-Maggio
# 10   214098       Goodwin, Homenick and Jerde
# 11   231907                        Hahn-Moore
# 12   242368      Frami, Anderson and Donnelly
# 13   268755                       Walsh-Haley
# 14   273274                     McDermott PLC
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          Texas
# ...

# %%
#to access from above
mydf.head(3)
# Out:
#    account                        name                                street  \
# 0   211829  Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1   320563              Walter-Trantow                     1311 Alvis Tunnel
# 2   648336  Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
#
#              city          state  postal-code    Jan     Feb    Mar
# 0      New Jaycob          Texas        28752  10000   62000  35000
# 1   Port Khadijah  NorthCarolina        38365  95000   45000  35000
# 2  New Lilianland           Iowa        76517  91000  120000  35000

# %%
#to access from bottom
mydf.tail(4)
# Out:
#     account                          name                    street  \
# 11   231907                    Hahn-Moore  18115 Olivine Throughway
# 12   242368  Frami, Anderson and Donnelly           182 Bertie Road
# 13   268755                   Walsh-Haley      2624 Beatty Parkways
# 14   273274                 McDermott PLC     8917 Bergstrom Meadow
#
#                city        state  postal-code     Jan     Feb     Mar
# 11    Norbertomouth  NorthDakota        31415  150000   10000  162000
# 12      East Davian         Iowa        72686  162000  120000   35000
# 13     Goodwinmouth  RhodeIsland        31919   55000  120000   35000
# 14  Kathryneborough     Delaware        27933  150000  120000   70000

# %%
mydf.keys()
# Out:
# Index(['account', 'name', 'street', 'city', 'state', 'postal-code', 'Jan',
#        'Feb', 'Mar'],
#       dtype='object')

# %%
type(mydf["account"])
# Out:
# pandas.core.series.Series

# %%
mydf[["account","name"]]
# Out:
#     account                              name
# 0    211829        Kerluke, Koepp and Hilpert
# 1    320563                    Walter-Trantow
# 2    648336        Bashirian, Kunde and Price
# 3    109996       D'Amore, Gleichner and Bode
# 4    121213                     Bauch-Goldner
# 5    132971  Williamson, Schumm and Hettinger
# 6    145068                        Casper LLC
# 7    205217                  Kovacek-Johnston
# 8    209744                    Champlin-Morar
# 9    212303                    Gerhold-Maggio
# 10   214098       Goodwin, Homenick and Jerde
# 11   231907                        Hahn-Moore
# 12   242368      Frami, Anderson and Donnelly
# 13   268755                       Walsh-Haley
# 14   273274                     McDermott PLC

# %%
type(mydf[["account","name"]])
# Out:
# pandas.core.frame.DataFrame

# %%
# access row wise
#.LOC
#.ILOC
mydf.iloc[0]
# Out:
# account                            211829
# name           Kerluke, Koepp and Hilpert
# street                 34456 Sean Highway
# city                           New Jaycob
# state                               Texas
# postal-code                         28752
# Jan                                 10000
# Feb                                 62000
# Mar                                 35000
# Name: 0, dtype: object

# %%
mydf.iloc[0:5]
# Out:
#    account                         name                                street  \
# 0   211829   Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1   320563               Walter-Trantow                     1311 Alvis Tunnel
# 2   648336   Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
# 3   109996  D'Amore, Gleichner and Bode           155 Fadel Crescent Apt. 144
# 4   121213                Bauch-Goldner                   7274 Marissa Common
#
#               city          state  postal-code     Jan     Feb    Mar
# 0       New Jaycob          Texas        28752   10000   62000  35000
# 1    Port Khadijah  NorthCarolina        38365   95000   45000  35000
# 2   New Lilianland           Iowa        76517   91000  120000  35000
# 3       Hyattburgh          Maine        46021   45000  120000  10000
# 4  Shanahanchester     California        49681  162000  120000  35000

# %%
mydf.iloc[0:5,1]
# Out:
# 0     Kerluke, Koepp and Hilpert
# 1                 Walter-Trantow
# 2     Bashirian, Kunde and Price
# 3    D'Amore, Gleichner and Bode
# 4                  Bauch-Goldner
# Name: name, dtype: object

# %%
mydf.iloc[:,1]
# Out:
# 0           Kerluke, Koepp and Hilpert
# 1                       Walter-Trantow
# 2           Bashirian, Kunde and Price
# 3          D'Amore, Gleichner and Bode
# 4                        Bauch-Goldner
# 5     Williamson, Schumm and Hettinger
# 6                           Casper LLC
# 7                     Kovacek-Johnston
# 8                       Champlin-Morar
# 9                       Gerhold-Maggio
# 10         Goodwin, Homenick and Jerde
# 11                          Hahn-Moore
# 12        Frami, Anderson and Donnelly
# 13                         Walsh-Haley
# 14                       McDermott PLC
# Name: name, dtype: object

# %%
mydf.iloc[::-1,::-1]
# Out:
#        Mar     Feb     Jan  postal-code          state               city  \
# 14   70000  120000  150000        27933       Delaware    Kathryneborough
# 13   35000  120000   55000        31919    RhodeIsland       Goodwinmouth
# 12   35000  120000  162000        72686           Iowa        East Davian
# 11  162000   10000  150000        31415    NorthDakota      Norbertomouth
# 10   55000  120000   45000        47743       Tenessee           Rosaberg
# 9    35000  120000   70000        46308          Idaho          North Ras
# 8    35000   95000   70000        64415   Pennsylvania    Lake Juliannton
# 7    35000   95000  145000        53461    RhodeIsland         Deronville
# 6    70000  120000   62000        18008     Mississipi  Lake Gabriellaton
# 5    35000  120000  150000        62785       Arkansas       Jeremieburgh
# 4    35000  120000  162000        49681     California    Shanahanchester
# 3    10000  120000   45000        46021          Maine         Hyattburgh
# ...

# %%
mydf.head(1)
# Out:
#    account                        name              street        city  state  \
# 0   211829  Kerluke, Koepp and Hilpert  34456 Sean Highway  New Jaycob  Texas
#
#    postal-code    Jan    Feb    Mar
# 0        28752  10000  62000  35000

# %%
#extract specific data
mydf["Total"]=mydf["Jan"]+mydf["Feb"]+mydf["Mar"]

# %%
mydf["Total"]
# Out:
# 0     107000
# 1     175000
# 2     246000
# 3     175000
# 4     317000
# 5     305000
# 6     252000
# 7     275000
# 8     200000
# 9     225000
# 10    220000
# 11    322000
# 12    317000
# 13    210000
# 14    340000
# Name: Total, dtype: int64

# %%
mydf["Total"].max()
# Out:
# 340000

# %%
mydf["Total"]==mydf["Total"].max()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# Name: Total, dtype: bool

# %%
mydf["Total"]==mydf["Total"].min()
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# Name: Total, dtype: bool

# %%
mydf[mydf["Total"]==mydf["Total"].max()]
# Out:
#     account           name                 street             city     state  \
# 14   273274  McDermott PLC  8917 Bergstrom Meadow  Kathryneborough  Delaware
#
#     postal-code     Jan     Feb    Mar   Total
# 14        27933  150000  120000  70000  340000

# %%
mydf[mydf["Jan"]==mydf["Jan"].max()]
# Out:
#     account                          name               street  \
# 4    121213                 Bauch-Goldner  7274 Marissa Common
# 12   242368  Frami, Anderson and Donnelly      182 Bertie Road
#
#                city       state  postal-code     Jan     Feb    Mar   Total
# 4   Shanahanchester  California        49681  162000  120000  35000  317000
# 12      East Davian        Iowa        72686  162000  120000  35000  317000
