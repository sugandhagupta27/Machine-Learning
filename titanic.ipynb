# %%
import pandas as pd

# %%
mytitandata=pd.read_csv(r"C:\Users\Naman\Desktop\Python\Datasets\DataSets-master\Titanic_Data.csv")

# %%
mytitandata
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
nfemale=mytitandata[mytitandata["Sex"]=="female"]

# %%
nfemale
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 14            15         0       3
# 15            16         1       2
# 18            19         0       3
# 19            20         1       3
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# 41            42         0       2
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 49            50         0       3
# ...

# %%
nmale=mytitandata[mytitandata["Sex"]=="male"]

# %%
nfsurv=nfemale[nfemale["Survived"]==1]

# %%
len(nfsurv)
# Out:
# 233

# %%
float(len(nfsurv)/len(nfemale))*100
# Out:
# 74.20382165605095

# %%
nmsurv=nmale[nmale["Survived"]==1]

# %%
float(len(nmsurv)/len(nmale))*100
# Out:
# 18.890814558058924

# %%
nsurvage=nfsurv[nfsurv["Age"]>38]

# %%
nsurvage
# Out:
#      PassengerId  Survived  Pclass  \
# 11            12         1       1
# 15            16         1       2
# 52            53         1       1
# 161          162         1       2
# 194          195         1       1
# 195          196         1       1
# 259          260         1       2
# 268          269         1       1
# 272          273         1       2
# 275          276         1       1
# 299          300         1       1
# 319          320         1       1
# 337          338         1       1
# 346          347         1       2
# 366          367         1       1
# 380          381         1       1
# 432          433         1       2
# 440          441         1       2
# 458          459         1       2
# 483          484         1       3
# 496          497         1       1
# 513          514         1       1
# 523          524         1       1
# 526          527         1       2
# 556          557         1       1
# ...

# %%
len(nsurvage)
# Out:
# 46
